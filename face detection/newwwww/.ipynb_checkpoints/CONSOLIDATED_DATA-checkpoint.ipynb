# %%
import cv2
import os  #operating system
import pickle   #compress the file
import numpy as np

# %%
data_dir = os.path.join(os.getcwd(),'data')
img_dir = os.path.join(os.getcwd(),'images')

# %%
print(os.getcwd()) #getcwd - get current working directory
print(data_dir)
print(img_dir)
# Out:
# C:\Users\surji\OneDrive\Desktop\face detection\newwwww
# C:\Users\surji\OneDrive\Desktop\face detection\newwwww\data
# C:\Users\surji\OneDrive\Desktop\face detection\newwwww\images

# %%
image_data = []
labels = []

# %%
for i in os.listdir(img_dir):
    print(i)
# Out:
# simran_0.jpg
# simran_1.jpg
# simran_10.jpg
# simran_11.jpg
# simran_12.jpg
# simran_13.jpg
# simran_14.jpg
# simran_15.jpg
# simran_16.jpg
# simran_17.jpg
# simran_18.jpg
# simran_19.jpg
# simran_2.jpg
# simran_20.jpg
# simran_21.jpg
# simran_22.jpg
# simran_23.jpg
# simran_24.jpg
# simran_25.jpg
# simran_26.jpg
# simran_27.jpg
# simran_28.jpg
# simran_29.jpg
# simran_3.jpg
# simran_30.jpg
# simran_31.jpg
# simran_32.jpg
# simran_33.jpg
# simran_34.jpg
# simran_35.jpg
# simran_36.jpg
# simran_37.jpg
# simran_38.jpg
# simran_39.jpg
# simran_4.jpg
# simran_40.jpg
# simran_41.jpg
# simran_42.jpg
# simran_43.jpg
# simran_44.jpg
# simran_45.jpg
# simran_46.jpg
# simran_47.jpg
# simran_48.jpg
# simran_49.jpg
# simran_5.jpg
# simran_50.jpg
# simran_51.jpg
# simran_52.jpg
# simran_53.jpg
# simran_54.jpg
# simran_55.jpg
# simran_56.jpg
# simran_57.jpg
# simran_58.jpg
# simran_59.jpg
# simran_6.jpg
# simran_60.jpg
# simran_61.jpg
# simran_62.jpg
# simran_63.jpg
# simran_64.jpg
# simran_65.jpg
# simran_66.jpg
# simran_67.jpg
# simran_68.jpg
# simran_69.jpg
# simran_7.jpg
# simran_70.jpg
# simran_71.jpg
# simran_72.jpg
# simran_73.jpg
# simran_74.jpg
# simran_75.jpg
# simran_76.jpg
# simran_77.jpg
# simran_78.jpg
# simran_79.jpg
# simran_8.jpg
# simran_80.jpg
# simran_81.jpg
# simran_82.jpg
# simran_83.jpg
# simran_84.jpg
# simran_85.jpg
# simran_86.jpg
# simran_87.jpg
# simran_88.jpg
# simran_89.jpg
# simran_9.jpg
# simran_90.jpg
# simran_91.jpg
# simran_92.jpg
# simran_93.jpg
# simran_94.jpg
# simran_95.jpg
# simran_96.jpg
# simran_97.jpg
# simran_98.jpg
# simran_99.jpg

# %%
for i in os.listdir(img_dir):
    image = cv2.imread(os.path.join(img_dir,i))
    image = cv2.resize(image,(100,100))
    image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    image_data.append(image)
    labels.append(str(i).split("_")[0])

# %%
image_data = np.array(image_data)    
labels = np.array(labels)

# %%
print(image_data)
# Out:
# [[[213 212 212 ... 205 209 205]
#   [214 213 212 ... 205 208 205]
#   [214 214 214 ... 207 207 201]
#   ...
#   [ 76  64  57 ...  60  66  59]
#   [ 75  66  68 ...  42  39  52]
#   [ 74  66  72 ...  60  58  63]]
#
#  [[216 216 216 ... 209 204 204]
#   [216 216 216 ... 204 204 204]
#   [216 216 214 ... 203 202 203]
#   ...
#   [ 62  60  52 ...  53  54  63]
#   [ 65  60  52 ...  54  65  56]
#   [ 68  61  61 ...  53  61  51]]
#
#  [[216 216 216 ... 196 196 197]
#   [216 216 216 ... 196 196 196]
#   [216 216 216 ... 194 194 195]
#   ...
#   [ 74  85  75 ...  80  61  65]
#   [ 74  84  75 ...  35  53  57]
#   [ 74  73  81 ...  49  64  47]]
#
#  ...
#
#  [[204 204 206 ... 174 199 205]
#   [204 204 206 ... 178 192 195]
#   [204 204 206 ... 184 185 175]
#   ...
#   [253 252 254 ...  37  46  67]
#   [252 251 254 ...  46  45  69]
#   [255 252 254 ...  36  47  61]]
#
#  [[206 206 206 ... 198 192 182]
#   [204 206 206 ... 206 200 181]
#   [204 206 206 ... 208 203 184]
#   ...
#   [252 253 253 ...  36  33  52]
#   [251 254 253 ...  48  30  32]
#   [251 255 253 ...  45  40  35]]
#
#  [[204 204 205 ... 207 155 204]
#   [204 204 205 ... 201 150 203]
#   [204 204 205 ... 191 177 204]
#   ...
#   [251 254 255 ...  20  37  48]
#   [250 254 251 ...  25  29  47]
#   [250 253 254 ...  26  25  30]]]

# %%
print(labels)
# Out:
# ['simran' 'simran' 'simran' 'simran' 'simran' 'simran' 'simran' 'simran'
#  'simran' 'simran' 'simran' 'simran' 'simran' 'simran' 'simran' 'simran'
#  'simran' 'simran' 'simran' 'simran' 'simran' 'simran' 'simran' 'simran'
#  'simran' 'simran' 'simran' 'simran' 'simran' 'simran' 'simran' 'simran'
#  'simran' 'simran' 'simran' 'simran' 'simran' 'simran' 'simran' 'simran'
#  'simran' 'simran' 'simran' 'simran' 'simran' 'simran' 'simran' 'simran'
#  'simran' 'simran' 'simran' 'simran' 'simran' 'simran' 'simran' 'simran'
#  'simran' 'simran' 'simran' 'simran' 'simran' 'simran' 'simran' 'simran'
#  'simran' 'simran' 'simran' 'simran' 'simran' 'simran' 'simran' 'simran'
#  'simran' 'simran' 'simran' 'simran' 'simran' 'simran' 'simran' 'simran'
#  'simran' 'simran' 'simran' 'simran' 'simran' 'simran' 'simran' 'simran'
#  'simran' 'simran' 'simran' 'simran' 'simran' 'simran' 'simran' 'simran'
#  'simran' 'simran' 'simran' 'simran']

# %%
import matplotlib.pyplot as plt
plt.imshow(image_data[50],cmap="gray")
plt.show()

# %%
with open(os.path.join(data_dir,"images.p"),'wb') as f:
    pickle.dump(image_data,f)

# %%
with open(os.path.join(data_dir,"labels.p"),'wb') as f:
    pickle.dump(labels,f)
